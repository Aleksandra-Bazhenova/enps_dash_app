# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\A_Bazhenova\\OneDrive - Domino Printing Sciences\\Documents\\0_my_documents\\0_projects\\6_enps\\enps_dash_app\\notebooks'

# %%
#data = pd.read_excel("../data/raw/global eNPS responses_June 2023.xlsx")
data = pd.read_csv("../data/raw/eNPS - Feb 2023 - all results.csv")

# %%
data
# Out:
#      Survey Question Response ID  \
# 0                a3h8e0000008WN2
# 1                a3h8e0000008WN1
# 2                a3h8e0000008WMx
# 3                a3h8e0000008WMw
# 4                a3h8e0000008WMs
# ...                          ...
# 4321             a3h8e0000004J2d
# 4322             a3h8e0000004J2Z
# 4323             a3h8e0000004J2Y
# 4324             a3h8e0000004J2U
# 4325             a3h8e0000004J2T
#
#                                          Question Title  Scale Score  \
# 0                               이렇게 평가한 가장 큰 이유는 무엇입니까?          NaN
# 1       도미노를직장으로 추천할 가능성이 얼마나 됩니까? 0부터10까지 척도로 표시해 주십시오          7.0
# 2                                        选择该分值的主要原因是什么？          NaN
# 3                    在从0到10的范围内，您推荐Domino作为工作场所的可能性有多大？         -1.0
# 4                               이렇게 평가한 가장 큰 이유는 무엇입니까?          NaN
# ...                                                 ...          ...
# 4321  On a scale from 0 to 10 how likely are you to ...          7.0
# 4322          What's the primary reason for your score?          NaN
# 4323  On a scale from 0 to 10 how likely are you to ...          9.0
# 4324  ¿Cuál ha sido el motivo que te ha llevado a se...          NaN
# 4325  En una escala del 0 al 10, ¿Recomendarías Domi...          7.0
#
#                                        Question Comment  \
# 0     직원들에 대한 처우 및 대우는 좋은 편이나 잡다한 일이나 업무가 너무 많음. 특히 ...
# 1                                                   NaN
# 2                                                     8
# 3                                                   NaN
# 4                          사측의 업계 최고 대우와 직원복지에 지속적인 관심.
# ...                                                 ...
# 4321                                                NaN
# 4322         Work culture and environment is very good.
# 4323                                                NaN
# 4324  Se nos excluyen de muchas actividades por "no ...
# 4325                                                NaN
#
#      Survey Response: Team Member: HR Department: Policy: Policy Name  \
# 0                                                 Korea
# 1                                                 Korea
# 2                                             China DPT
# 3                                             China DPT
# 4                                                 Korea
# ...                                                 ...
# 4321                                              India
# 4322                                              India
# 4323                                              India
# 4324                                             Mexico
# 4325                                             Mexico
#
#      Survey Response: Team Member: Gender  \
# 0                                    Male
# 1                                    Male
# 2                                    Male
# 3                                    Male
# 4                                    Male
# ...                                   ...
# 4321                                 Male
# 4322                                 Male
# 4323                                 Male
# 4324                               Female
# 4325                               Female
#
#      Survey Response: Team Member: Current Employment: Division  \
# 0                                      Coding & Marking
# 1                                      Coding & Marking
# 2                                      Coding & Marking
# 3                                      Coding & Marking
# 4                                      Coding & Marking
# ...                                                 ...
# 4321                                   Coding & Marking
# 4322                                   Coding & Marking
# 4323                                   Coding & Marking
# 4324                                   Coding & Marking
# 4325                                   Coding & Marking
#
#       Survey Response: Team Member: Current Employment: Service Years  \
# 0                                                     5
# 1                                                     5
# 2                                                     1
# 3                                                     1
# 4                                                    13
# ...                                                 ...
# 4321                                                  5
# 4322                                                  9
# 4323                                                  9
# 4324                                                  4
# 4325                                                  4
#
#      Survey Response: Team Member: Current Employment: Department  \
# 0                                   Field Based Service
# 1                                   Field Based Service
# 2                                            Facilities
# 3                                            Facilities
# 4                                                 Sales
# ...                                                 ...
# 4321                                           Planning
# 4322                           General Management/Admin
# 4323                           General Management/Admin
# 4324                                        Aftermarket
# 4325                                        Aftermarket
#
#      Survey Response: Team Member: Company  \
# 0                     Domino Korea Pte Ltd
# 1                     Domino Korea Pte Ltd
# 2           Domino Printing Technology Ltd
# 3           Domino Printing Technology Ltd
# 4                     Domino Korea Pte Ltd
# ...                                    ...
# 4321             Domino Printech India LLP
# 4322             Domino Printech India LLP
# 4323             Domino Printech India LLP
# 4324       Domino Printing Mexico SA de CV
# 4325       Domino Printing Mexico SA de CV
#
#      Survey Response: Team Member: Function  \
# 0                                   Service
# 1                                   Service
# 2                            Administration
# 3                            Administration
# 4                    Selling & Distribution
# ...                                     ...
# 4321        Indirect Manufacturing Printers
# 4322                          Sales Support
# 4323                          Sales Support
# 4324                 Selling & Distribution
# 4325                 Selling & Distribution
#
#      Survey Response: Team Member: Country  \
# 0                       Korea, Republic Of
# 1                       Korea, Republic Of
# 2                                    China
# 3                                    China
# 4                       Korea, Republic Of
# ...                                    ...
# 4321                                 India
# 4322                                 India
# 4323                                 India
# 4324                                Mexico
# 4325                                Mexico
#
#      Survey Response: Team Member: Manager: Name
# 0                                       심민욱 Shim
# 1                                       심민욱 Shim
# 2                                   Jeanva Liang
# 3                                   Jeanva Liang
# 4                                        주영철 Joo
# ...                                          ...
# 4321                                  Ratheesh K
# 4322                                  Ratheesh K
# 4323                                  Ratheesh K
# 4324                          Brenda Karaszewski
# 4325                          Brenda Karaszewski
#
# [4326 rows x 13 columns]

# %%
list(data.columns)
# Out:
# ['Survey Question Response ID',
#  'Question Title',
#  'Scale Score',
#  'Question Comment',
#  'Survey Response: Team Member: HR Department: Policy: Policy Name',
#  'Survey Response: Team Member: Gender',
#  'Survey Response: Team Member: Current Employment: Division',
#  'Survey Response: Team Member: Current Employment: Service Years',
#  'Survey Response: Team Member: Current Employment: Department',
#  'Survey Response: Team Member: Company',
#  'Survey Response: Team Member: Function',
#  'Survey Response: Team Member: Country',
#  'Survey Response: Team Member: Manager: Name']

# %%
['index', 'Question Title', 'Scale Score']+[c for c in data.columns if c not in ['index', 'Question Title', 'Scale Score']]
# Out:
# ['index',
#  'Question Title',
#  'Scale Score',
#  'Survey Question Response ID',
#  'Question Comment',
#  'Survey Response: Team Member: HR Department: Policy: Policy Name',
#  'Survey Response: Team Member: Gender',
#  'Survey Response: Team Member: Current Employment: Division',
#  'Survey Response: Team Member: Current Employment: Service Years',
#  'Survey Response: Team Member: Current Employment: Department',
#  'Survey Response: Team Member: Company',
#  'Survey Response: Team Member: Function',
#  'Survey Response: Team Member: Country',
#  'Survey Response: Team Member: Manager: Name']

# %%
def data_reshaping(data):
    
    if ~data['Scale Score'].isnull()[0]:
        data['Score or Comment'] = ['Score', 'Comment']*int(len(data)/2)
        data_comments = data.loc[list(range(1, len(data), 2))].reset_index().rename(columns={'index':'Comment Original Index', 'Question Title':'Comment Question Title'})
        data_scores = data.loc[list(range(0, len(data), 2))].reset_index().rename(columns={'index':'Score Original Index', 'Question Title':'Score Question Title'})
        
    else:
        data['Score or Comment'] = ['Comment', 'Score']*int(len(data)/2)
        data_comments = data.loc[list(range(0, len(data), 2))].reset_index().rename(columns={'index':'Comment Original Index', 'Question Title':'Comment Question Title'})
        data_scores = data.loc[list(range(1, len(data), 2))].reset_index().rename(columns={'index':'Score Original Index', 'Question Title':'Score Question Title'})
    
    data_wide = pd.concat([data_scores[['Score Original Index', 'Score Question Title', 'Scale Score']], data_comments[[c for c in data_comments.columns if c not in ['Score Original Index', 'Score Question Title', 'Scale Score', 'Score or Comment']]]], axis=1)
    
    return data_wide

# %%
df = data_reshaping(data)
df
# Out:
#       Score Original Index                               Score Question Title  \
# 0                        1  On a scale from 0 to 10 how likely are you to ...
# 1                        3  Numa escala de 0 a 10, qual a probabilidade de...
# 2                        5  Sur une échelle de 0 à 10, quelle est la proba...
# 3                        7  En una escala del 0 al 10, ¿Recomendarías Domi...
# 4                        9  En una escala del 0 al 10, ¿Recomendarías Domi...
# ...                    ...                                                ...
# 2045                  4091                 在从0到10的范围内，您推荐Domino作为工作场所的可能性有多大？
# 2046                  4093                 在从0到10的范围内，您推荐Domino作为工作场所的可能性有多大？
# 2047                  4095                 在从0到10的范围内，您推荐Domino作为工作场所的可能性有多大？
# 2048                  4097                 在从0到10的范围内，您推荐Domino作为工作场所的可能性有多大？
# 2049                  4099                 在从0到10的范围内，您推荐Domino作为工作场所的可能性有多大？
#
#       Scale Score  Comment Original Index  \
# 0            10.0                       0
# 1             4.0                       2
# 2            10.0                       4
# 3             9.0                       6
# 4             9.0                       8
# ...           ...                     ...
# 2045          9.0                    4090
# 2046          5.0                    4092
# 2047         10.0                    4094
# 2048          6.0                    4096
# 2049         10.0                    4098
#
#                                  Comment Question Title  \
# 0             What's the primary reason for your score?
# 1           Qual é o principal motivo da sua pontuação?
# 2       Quelle est la raison principale de votre score?
# 3     ¿Cuál ha sido el motivo que te ha llevado a se...
# 4     ¿Cuál ha sido el motivo que te ha llevado a se...
# ...                                                 ...
# 2045                                     选择该分值的主要原因是什么？
# 2046                                     选择该分值的主要原因是什么？
# 2047                                     选择该分值的主要原因是什么？
# 2048                                     选择该分值的主要原因是什么？
# 2049                                     选择该分值的主要原因是什么？
#
#                                        Question Comment Question Response #  \
# 0                                    Happy doing my job  SQR-2023.06 #47652
# 1     Desde que a administração está foçada em Espan...  SQR-2023.06 #47650
# 2                               Possibilité d'évolution  SQR-2023.06 #47648
# 3     Traspasar toda la información o especificacion...  SQR-2023.06 #47646
# 4     Como bien se comentó la última vez…el dormir f...  SQR-2023.06 #47644
# ...                                                 ...                 ...
# 2045                                          工作环境，学习机会  SQR-2023.06 #43546
# 2046                                工资薪水低，福利待遇差，自我发展空间小  SQR-2023.06 #43544
# 2047                                       公司文化和工作氛围非常棒  SQR-2023.06 #43542
# 2048                                                  无  SQR-2023.06 #43540
# 2049                                                NaN  SQR-2023.06 #43538
#
#      Survey Response: Team Member: Function  \
# 0                                   Service
# 1             Indirect Manufacturing Fluids
# 2                                   Service
# 3                                   Service
# 4                                   Service
# ...                                     ...
# 2045        Indirect Manufacturing Printers
# 2046          Direct Manufacturing Printers
# 2047                 Selling & Distribution
# 2048                          Sales Support
# 2049                         Administration
#
#      Survey Response: Team Member: Current Employment: Contract Type
# 0                                             Permanent
# 1                                   Fixed Term Contract
# 2                                             Permanent
# 3                                             Permanent
# 4                                             Permanent
# ...                                                 ...
# 2045                                          Permanent
# 2046                                          Permanent
# 2047                                          Permanent
# 2048                                          Permanent
# 2049                                          Permanent
#
# [2050 rows x 9 columns]
